# %%
"""
Multi-step ahead forecasting
Forecasting n_ahead steps all at once using a GRU network
with a Conv1D layer to help GRU layers detect longer
patterns
"""

#Imports
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
#Load Data
data = pd.read_csv('data/AEP_hourly.csv', index_col=0, parse_dates=True)

#Sort the dataframe
data.sort_values('Datetime', inplace=True)

#scale the timeseries using standard scaler
ts = np.asarray(data['AEP_MW']).reshape(-1,1)
scaler = preprocessing.StandardScaler().fit(ts)
ts_scaled = list(scaler.transform(ts))

# %%
#create 3D array of timeseries of fixed length
n_ahead = 24
n_lag = n_ahead*20

max_idx = int(np.floor(len(ts_scaled) / (n_lag + n_ahead)))

i=0
series = []
for i in range(0, max_idx):
    n = n_lag + n_ahead
    series.append(ts_scaled[i*n : (i+1) * n])

#create training matrix and target vector
X = np.asarray(series)[:,0:n_lag,:]
y_plot = np.asarray(series)[:,n_lag:,:].squeeze()
y = np.empty((np.shape(X)[0], np.shape(X)[1], n_ahead))


for i in range(1, n_ahead+1):
    y[:,:,i-1] = np.asarray(series)[:,i:i+n_lag,0]

# %%
#create training, validation, and testing sets
train_valid_test = [0.7,0.2,0.1]
train_valid_test_idx = np.floor(np.asarray(train_valid_test) * max_idx).astype(int)
X_train, y_train = X[0:train_valid_test_idx[0],:,:], y[0:train_valid_test_idx[0],:,:]
X_valid, y_valid = X[0:train_valid_test_idx[1],:,:], y[0:train_valid_test_idx[1],:,:]
X_test, y_test = X[0:train_valid_test_idx[2],:,:], y[0:train_valid_test_idx[2],:,:]

# %%
#LSTM
num_neurons = 30
ker_size = 4
stride = 2

model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=ker_size, strides=stride, padding='Valid',
        input_shape=[None,1]),
    keras.layers.GRU(num_neurons, return_sequences=True),
    keras.layers.GRU(num_neurons, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(n_ahead))
    ])

#custom loss function
def last_timestep_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:,-1], Y_pred[:,-1])

#compile model
lr = 0.01
opt = keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=opt, loss='mse', metrics=[last_timestep_mse])

epochs = 50

#create a dict for keras training args
keras_dict = {
    'x':X_train,
    'y':y_train[:, ker_size-1::stride],
    'epochs':epochs,
    'shuffle':False,
    'validation_data':(X_valid,y_valid[:, ker_size-1::stride])
}

#fit the model
history = model.fit(**keras_dict)
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function last_timestep_mse at 0x0000029E9BD1B5E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function last_timestep_mse at 0x0000029E9BD1B5E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 6/6 [==============================] - 1s 163ms/step - loss: 0.7920 - last_timestep_mse: 0.8725 - val_loss: 0.6056 - val_last_timestep_mse: 0.5724
# Epoch 2/50
# 6/6 [==============================] - 0s 73ms/step - loss: 0.5767 - last_timestep_mse: 0.5875 - val_loss: 0.5165 - val_last_timestep_mse: 0.5046
# Epoch 3/50
# 6/6 [==============================] - 0s 74ms/step - loss: 0.4796 - last_timestep_mse: 0.4756 - val_loss: 0.4139 - val_last_timestep_mse: 0.3641
# Epoch 4/50
# 6/6 [==============================] - 0s 74ms/step - loss: 0.3782 - last_timestep_mse: 0.3403 - val_loss: 0.3501 - val_last_timestep_mse: 0.3008
# Epoch 5/50
# 6/6 [==============================] - 0s 70ms/step - loss: 0.3222 - last_timestep_mse: 0.2738 - val_loss: 0.3112 - val_last_timestep_mse: 0.3026
# Epoch 6/50
# 6/6 [==============================] - 0s 74ms/step - loss: 0.2878 - last_timestep_mse: 0.2612 - val_loss: 0.2940 - val_last_timestep_mse: 0.2728
# Epoch 7/50
# 6/6 [==============================] - 0s 72ms/step - loss: 0.2705 - last_timestep_mse: 0.2371 - val_loss: 0.2668 - val_last_timestep_mse: 0.2390
# Epoch 8/50
# 6/6 [==============================] - 0s 71ms/step - loss: 0.2487 - last_timestep_mse: 0.2123 - val_loss: 0.2470 - val_last_timestep_mse: 0.2070
# Epoch 9/50
# 6/6 [==============================] - 0s 76ms/step - loss: 0.2345 - last_timestep_mse: 0.1941 - val_loss: 0.2459 - val_last_timestep_mse: 0.2375
# Epoch 10/50
# 6/6 [==============================] - 0s 76ms/step - loss: 0.2277 - last_timestep_mse: 0.1871 - val_loss: 0.2151 - val_last_timestep_mse: 0.1729
# Epoch 11/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.2076 - last_timestep_mse: 0.1591 - val_loss: 0.2049 - val_last_timestep_mse: 0.1868
# Epoch 12/50
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1955 - last_timestep_mse: 0.1574 - val_loss: 0.1936 - val_last_timestep_mse: 0.1622
# Epoch 13/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1887 - last_timestep_mse: 0.1438 - val_loss: 0.1921 - val_last_timestep_mse: 0.1485
# Epoch 14/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1833 - last_timestep_mse: 0.1360 - val_loss: 0.1858 - val_last_timestep_mse: 0.1750
# Epoch 15/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1794 - last_timestep_mse: 0.1358 - val_loss: 0.1796 - val_last_timestep_mse: 0.1427
# Epoch 16/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1716 - last_timestep_mse: 0.1255 - val_loss: 0.1860 - val_last_timestep_mse: 0.2077
# Epoch 17/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1729 - last_timestep_mse: 0.1432 - val_loss: 0.1526 - val_last_timestep_mse: 0.1490
# Epoch 18/50
# 6/6 [==============================] - 0s 70ms/step - loss: 0.1554 - last_timestep_mse: 0.1224 - val_loss: 0.1506 - val_last_timestep_mse: 0.1368
# Epoch 19/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1501 - last_timestep_mse: 0.1171 - val_loss: 0.1500 - val_last_timestep_mse: 0.1359
# Epoch 20/50
# 6/6 [==============================] - 0s 70ms/step - loss: 0.1500 - last_timestep_mse: 0.1163 - val_loss: 0.1583 - val_last_timestep_mse: 0.1340
# Epoch 21/50
# 6/6 [==============================] - 0s 71ms/step - loss: 0.1521 - last_timestep_mse: 0.1131 - val_loss: 0.1580 - val_last_timestep_mse: 0.1383
# Epoch 22/50
# 6/6 [==============================] - 0s 70ms/step - loss: 0.1542 - last_timestep_mse: 0.1164 - val_loss: 0.1710 - val_last_timestep_mse: 0.1429
# Epoch 23/50
# 6/6 [==============================] - 0s 72ms/step - loss: 0.1564 - last_timestep_mse: 0.1164 - val_loss: 0.1588 - val_last_timestep_mse: 0.1590
# Epoch 24/50
# 6/6 [==============================] - 0s 72ms/step - loss: 0.1527 - last_timestep_mse: 0.1191 - val_loss: 0.1433 - val_last_timestep_mse: 0.1479
# Epoch 25/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1420 - last_timestep_mse: 0.1125 - val_loss: 0.1368 - val_last_timestep_mse: 0.1262
# Epoch 26/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1391 - last_timestep_mse: 0.1079 - val_loss: 0.1411 - val_last_timestep_mse: 0.1273
# Epoch 27/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1391 - last_timestep_mse: 0.1050 - val_loss: 0.1358 - val_last_timestep_mse: 0.1322
# Epoch 28/50
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1356 - last_timestep_mse: 0.1041 - val_loss: 0.1285 - val_last_timestep_mse: 0.1321
# Epoch 29/50
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1310 - last_timestep_mse: 0.1047 - val_loss: 0.1274 - val_last_timestep_mse: 0.1260
# Epoch 30/50
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1290 - last_timestep_mse: 0.1009 - val_loss: 0.1271 - val_last_timestep_mse: 0.1207
# Epoch 31/50
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1279 - last_timestep_mse: 0.0970 - val_loss: 0.1270 - val_last_timestep_mse: 0.1153
# Epoch 32/50
# 6/6 [==============================] - 0s 72ms/step - loss: 0.1286 - last_timestep_mse: 0.0945 - val_loss: 0.1278 - val_last_timestep_mse: 0.1151
# Epoch 33/50
# 6/6 [==============================] - 0s 71ms/step - loss: 0.1305 - last_timestep_mse: 0.0969 - val_loss: 0.1305 - val_last_timestep_mse: 0.1151
# Epoch 34/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1313 - last_timestep_mse: 0.0974 - val_loss: 0.1321 - val_last_timestep_mse: 0.1258
# Epoch 35/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1313 - last_timestep_mse: 0.1011 - val_loss: 0.1310 - val_last_timestep_mse: 0.1198
# Epoch 36/50
# 6/6 [==============================] - 0s 70ms/step - loss: 0.1286 - last_timestep_mse: 0.1011 - val_loss: 0.1247 - val_last_timestep_mse: 0.1239
# Epoch 37/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1290 - last_timestep_mse: 0.1013 - val_loss: 0.1312 - val_last_timestep_mse: 0.1104
# Epoch 38/50
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1267 - last_timestep_mse: 0.0921 - val_loss: 0.1377 - val_last_timestep_mse: 0.1452
# Epoch 39/50
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1331 - last_timestep_mse: 0.1053 - val_loss: 0.1212 - val_last_timestep_mse: 0.1144
# Epoch 40/50
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1305 - last_timestep_mse: 0.0994 - val_loss: 0.1243 - val_last_timestep_mse: 0.1214
# Epoch 41/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1309 - last_timestep_mse: 0.0999 - val_loss: 0.1422 - val_last_timestep_mse: 0.1320
# Epoch 42/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1352 - last_timestep_mse: 0.1018 - val_loss: 0.1570 - val_last_timestep_mse: 0.1847
# Epoch 43/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1407 - last_timestep_mse: 0.1148 - val_loss: 0.1565 - val_last_timestep_mse: 0.2201
# Epoch 44/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1406 - last_timestep_mse: 0.1275 - val_loss: 0.1253 - val_last_timestep_mse: 0.1225
# Epoch 45/50
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1298 - last_timestep_mse: 0.0996 - val_loss: 0.1345 - val_last_timestep_mse: 0.1193
# Epoch 46/50
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1269 - last_timestep_mse: 0.0926 - val_loss: 0.1210 - val_last_timestep_mse: 0.1276
# Epoch 47/50
# 6/6 [==============================] - 0s 79ms/step - loss: 0.1201 - last_timestep_mse: 0.0908 - val_loss: 0.1237 - val_last_timestep_mse: 0.1336
# Epoch 48/50
# 6/6 [==============================] - 1s 83ms/step - loss: 0.1213 - last_timestep_mse: 0.0973 - val_loss: 0.1249 - val_last_timestep_mse: 0.1156
# Epoch 49/50
# 6/6 [==============================] - 1s 91ms/step - loss: 0.1210 - last_timestep_mse: 0.0947 - val_loss: 0.1236 - val_last_timestep_mse: 0.1269
# Epoch 50/50
# 6/6 [==============================] - 1s 84ms/step - loss: 0.1190 - last_timestep_mse: 0.0921 - val_loss: 0.1262 - val_last_timestep_mse: 0.1447

# %%
#Plot Training Results
hist_df = pd.DataFrame(history.history)
hist_df.plot()
plt.grid(True)
plt.title('Training Performance')
plt.xlabel('epoch')
plt.show()

# %%
#predict
y_pred = model.predict((X_test[0])[np.newaxis,...])

#Inverse transform scaled data
y_true = scaler.inverse_transform(y_test[0,-1].reshape(-1,1))
y_pred = scaler.inverse_transform(y_pred.squeeze()[-1,:].reshape(-1,1))

plt.plot(y_true,label='true')
plt.plot(y_pred,'r',label='prediction')
plt.legend()
plt.xlabel('hour')
plt.ylabel('MW')
plt.show()

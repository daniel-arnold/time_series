# %%
"""
Multi-step ahead forecasting
Forecasting n_ahead steps all at once using a LSTM network
"""

#Imports
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
#Load Data
data = pd.read_csv('data/AEP_hourly.csv', index_col=0, parse_dates=True)

#Sort the dataframe
data.sort_values('Datetime', inplace=True)

#scale the timeseries using standard scaler
ts = np.asarray(data['AEP_MW']).reshape(-1,1)
scaler = preprocessing.StandardScaler().fit(ts)
ts_scaled = list(scaler.transform(ts))

# %%
#create 3D array of timeseries of fixed length
n_ahead = 24
n_lag = n_ahead*14

max_idx = int(np.floor(len(ts_scaled) / (n_lag + n_ahead)))

i=0
series = []
for i in range(0, max_idx):
    n = n_lag + n_ahead
    series.append(ts_scaled[i*n : (i+1) * n])

#create training matrix and target vector
X = np.asarray(series)[:,0:n_lag,:]
y_plot = np.asarray(series)[:,n_lag:,:].squeeze()
y = np.empty((np.shape(X)[0], np.shape(X)[1], n_ahead))


for i in range(1, n_ahead+1):
    y[:,:,i-1] = np.asarray(series)[:,i:i+n_lag,0]

# %%
#create training, validation, and testing sets
train_valid_test = [0.7,0.2,0.1]
train_valid_test_idx = np.floor(np.asarray(train_valid_test) * max_idx).astype(int)
X_train, y_train = X[0:train_valid_test_idx[0],:,:], y[0:train_valid_test_idx[0],:,:]
X_valid, y_valid = X[0:train_valid_test_idx[1],:,:], y[0:train_valid_test_idx[1],:,:]
X_test, y_test = X[0:train_valid_test_idx[2],:,:], y[0:train_valid_test_idx[2],:,:]

# %%
#LSTM
num_neurons = 20
model = keras.models.Sequential([
    keras.layers.LSTM(num_neurons, return_sequences=True, input_shape=[None,1]),
    keras.layers.LSTM(num_neurons, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(n_ahead))
    ])

#custom loss function
def last_timestep_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:,-1], Y_pred[:,-1])

#compile model
lr = 0.01
opt = keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=opt, loss='mse', metrics=[last_timestep_mse])

epochs = 200

#create a dict for keras training args
keras_dict = {
    'x':X_train,
    'y':y_train,
    'epochs':epochs,
    'shuffle':False,
    'validation_data':(X_valid,y_valid)
}

#fit the model
model.fit(**keras_dict)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function last_timestep_mse at 0x000002A3972DC3A0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function last_timestep_mse at 0x000002A3972DC3A0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 1s 154ms/step - loss: 0.8371 - last_timestep_mse: 0.8208 - val_loss: 0.6642 - val_last_timestep_mse: 0.6213
# Epoch 2/200
# 8/8 [==============================] - 1s 90ms/step - loss: 0.6464 - last_timestep_mse: 0.6291 - val_loss: 0.5983 - val_last_timestep_mse: 0.5772
# Epoch 3/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5872 - last_timestep_mse: 0.5802 - val_loss: 0.5434 - val_last_timestep_mse: 0.5559
# Epoch 4/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.5144 - last_timestep_mse: 0.5023 - val_loss: 0.4545 - val_last_timestep_mse: 0.4911
# Epoch 5/200
# 8/8 [==============================] - 1s 86ms/step - loss: 0.4321 - last_timestep_mse: 0.4117 - val_loss: 0.3803 - val_last_timestep_mse: 0.4153
# Epoch 6/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.3631 - last_timestep_mse: 0.3531 - val_loss: 0.3327 - val_last_timestep_mse: 0.3626
# Epoch 7/200
# 8/8 [==============================] - 1s 88ms/step - loss: 0.3216 - last_timestep_mse: 0.3094 - val_loss: 0.2981 - val_last_timestep_mse: 0.3328
# Epoch 8/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.2929 - last_timestep_mse: 0.2829 - val_loss: 0.2751 - val_last_timestep_mse: 0.3187
# Epoch 9/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.2727 - last_timestep_mse: 0.2601 - val_loss: 0.2836 - val_last_timestep_mse: 0.3403
# Epoch 10/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2821 - last_timestep_mse: 0.2625 - val_loss: 0.3312 - val_last_timestep_mse: 0.3620
# Epoch 11/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.2890 - last_timestep_mse: 0.2709 - val_loss: 0.2602 - val_last_timestep_mse: 0.2906
# Epoch 12/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.2590 - last_timestep_mse: 0.2465 - val_loss: 0.2589 - val_last_timestep_mse: 0.2942
# Epoch 13/200
# 8/8 [==============================] - 1s 90ms/step - loss: 0.2541 - last_timestep_mse: 0.2414 - val_loss: 0.2552 - val_last_timestep_mse: 0.3117
# Epoch 14/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.2493 - last_timestep_mse: 0.2367 - val_loss: 0.2575 - val_last_timestep_mse: 0.3149
# Epoch 15/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2433 - last_timestep_mse: 0.2352 - val_loss: 0.2683 - val_last_timestep_mse: 0.3669
# Epoch 16/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.2482 - last_timestep_mse: 0.2426 - val_loss: 0.2787 - val_last_timestep_mse: 0.4011
# Epoch 17/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.2592 - last_timestep_mse: 0.2650 - val_loss: 0.2334 - val_last_timestep_mse: 0.2864
# Epoch 18/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.2402 - last_timestep_mse: 0.2356 - val_loss: 0.2239 - val_last_timestep_mse: 0.2535
# Epoch 19/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.2246 - last_timestep_mse: 0.2075 - val_loss: 0.2095 - val_last_timestep_mse: 0.2503
# Epoch 20/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2165 - last_timestep_mse: 0.2006 - val_loss: 0.2052 - val_last_timestep_mse: 0.2474
# Epoch 21/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2127 - last_timestep_mse: 0.1961 - val_loss: 0.2019 - val_last_timestep_mse: 0.2464
# Epoch 22/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2079 - last_timestep_mse: 0.1925 - val_loss: 0.1923 - val_last_timestep_mse: 0.2332
# Epoch 23/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2004 - last_timestep_mse: 0.1853 - val_loss: 0.1817 - val_last_timestep_mse: 0.2132
# Epoch 24/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1926 - last_timestep_mse: 0.1765 - val_loss: 0.1787 - val_last_timestep_mse: 0.2035
# Epoch 25/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1885 - last_timestep_mse: 0.1703 - val_loss: 0.1786 - val_last_timestep_mse: 0.2066
# Epoch 26/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1872 - last_timestep_mse: 0.1690 - val_loss: 0.1772 - val_last_timestep_mse: 0.2051
# Epoch 27/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1849 - last_timestep_mse: 0.1667 - val_loss: 0.1760 - val_last_timestep_mse: 0.1994
# Epoch 28/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1813 - last_timestep_mse: 0.1645 - val_loss: 0.1756 - val_last_timestep_mse: 0.1976
# Epoch 29/200
# 8/8 [==============================] - 1s 120ms/step - loss: 0.1800 - last_timestep_mse: 0.1659 - val_loss: 0.1649 - val_last_timestep_mse: 0.1744
# Epoch 30/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.1739 - last_timestep_mse: 0.1566 - val_loss: 0.1620 - val_last_timestep_mse: 0.1737
# Epoch 31/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1706 - last_timestep_mse: 0.1518 - val_loss: 0.1673 - val_last_timestep_mse: 0.1802
# Epoch 32/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1721 - last_timestep_mse: 0.1527 - val_loss: 0.1719 - val_last_timestep_mse: 0.1926
# Epoch 33/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1730 - last_timestep_mse: 0.1559 - val_loss: 0.1728 - val_last_timestep_mse: 0.1999
# Epoch 34/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1757 - last_timestep_mse: 0.1621 - val_loss: 0.1675 - val_last_timestep_mse: 0.1879
# Epoch 35/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1732 - last_timestep_mse: 0.1589 - val_loss: 0.1627 - val_last_timestep_mse: 0.1609
# Epoch 36/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1684 - last_timestep_mse: 0.1478 - val_loss: 0.1639 - val_last_timestep_mse: 0.1634
# Epoch 37/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1638 - last_timestep_mse: 0.1444 - val_loss: 0.1599 - val_last_timestep_mse: 0.1643
# Epoch 38/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1615 - last_timestep_mse: 0.1458 - val_loss: 0.1596 - val_last_timestep_mse: 0.1604
# Epoch 39/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1633 - last_timestep_mse: 0.1436 - val_loss: 0.1579 - val_last_timestep_mse: 0.1679
# Epoch 40/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1626 - last_timestep_mse: 0.1453 - val_loss: 0.1661 - val_last_timestep_mse: 0.1778
# Epoch 41/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1676 - last_timestep_mse: 0.1492 - val_loss: 0.1670 - val_last_timestep_mse: 0.1751
# Epoch 42/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1655 - last_timestep_mse: 0.1451 - val_loss: 0.1582 - val_last_timestep_mse: 0.1636
# Epoch 43/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1598 - last_timestep_mse: 0.1416 - val_loss: 0.1447 - val_last_timestep_mse: 0.1364
# Epoch 44/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1514 - last_timestep_mse: 0.1309 - val_loss: 0.1491 - val_last_timestep_mse: 0.1437
# Epoch 45/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1523 - last_timestep_mse: 0.1300 - val_loss: 0.1572 - val_last_timestep_mse: 0.1597
# Epoch 46/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1548 - last_timestep_mse: 0.1351 - val_loss: 0.1662 - val_last_timestep_mse: 0.1725
# Epoch 47/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1611 - last_timestep_mse: 0.1465 - val_loss: 0.1568 - val_last_timestep_mse: 0.1728
# Epoch 48/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1602 - last_timestep_mse: 0.1474 - val_loss: 0.1478 - val_last_timestep_mse: 0.1379
# Epoch 49/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1518 - last_timestep_mse: 0.1320 - val_loss: 0.1456 - val_last_timestep_mse: 0.1359
# Epoch 50/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1497 - last_timestep_mse: 0.1255 - val_loss: 0.1466 - val_last_timestep_mse: 0.1421
# Epoch 51/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1471 - last_timestep_mse: 0.1270 - val_loss: 0.1515 - val_last_timestep_mse: 0.1485
# Epoch 52/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1500 - last_timestep_mse: 0.1311 - val_loss: 0.1466 - val_last_timestep_mse: 0.1484
# Epoch 53/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1481 - last_timestep_mse: 0.1317 - val_loss: 0.1410 - val_last_timestep_mse: 0.1323
# Epoch 54/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1443 - last_timestep_mse: 0.1250 - val_loss: 0.1465 - val_last_timestep_mse: 0.1437
# Epoch 55/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1467 - last_timestep_mse: 0.1274 - val_loss: 0.1462 - val_last_timestep_mse: 0.1413
# Epoch 56/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1473 - last_timestep_mse: 0.1246 - val_loss: 0.1435 - val_last_timestep_mse: 0.1358
# Epoch 57/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1424 - last_timestep_mse: 0.1196 - val_loss: 0.1410 - val_last_timestep_mse: 0.1375
# Epoch 58/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1417 - last_timestep_mse: 0.1201 - val_loss: 0.1371 - val_last_timestep_mse: 0.1343
# Epoch 59/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1408 - last_timestep_mse: 0.1223 - val_loss: 0.1346 - val_last_timestep_mse: 0.1352
# Epoch 60/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1380 - last_timestep_mse: 0.1211 - val_loss: 0.1368 - val_last_timestep_mse: 0.1303
# Epoch 61/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1356 - last_timestep_mse: 0.1165 - val_loss: 0.1312 - val_last_timestep_mse: 0.1247
# Epoch 62/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1324 - last_timestep_mse: 0.1134 - val_loss: 0.1330 - val_last_timestep_mse: 0.1275
# Epoch 63/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1333 - last_timestep_mse: 0.1141 - val_loss: 0.1386 - val_last_timestep_mse: 0.1394
# Epoch 64/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1363 - last_timestep_mse: 0.1187 - val_loss: 0.1395 - val_last_timestep_mse: 0.1386
# Epoch 65/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1365 - last_timestep_mse: 0.1193 - val_loss: 0.1355 - val_last_timestep_mse: 0.1298
# Epoch 66/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1352 - last_timestep_mse: 0.1163 - val_loss: 0.1318 - val_last_timestep_mse: 0.1242
# Epoch 67/200
# 8/8 [==============================] - 1s 136ms/step - loss: 0.1340 - last_timestep_mse: 0.1164 - val_loss: 0.1275 - val_last_timestep_mse: 0.1214
# Epoch 68/200
# 8/8 [==============================] - 1s 119ms/step - loss: 0.1306 - last_timestep_mse: 0.1106 - val_loss: 0.1275 - val_last_timestep_mse: 0.1151
# Epoch 69/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1285 - last_timestep_mse: 0.1041 - val_loss: 0.1336 - val_last_timestep_mse: 0.1178
# Epoch 70/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1308 - last_timestep_mse: 0.1069 - val_loss: 0.1347 - val_last_timestep_mse: 0.1250
# Epoch 71/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1326 - last_timestep_mse: 0.1127 - val_loss: 0.1368 - val_last_timestep_mse: 0.1311
# Epoch 72/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1343 - last_timestep_mse: 0.1171 - val_loss: 0.1319 - val_last_timestep_mse: 0.1162
# Epoch 73/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1297 - last_timestep_mse: 0.1129 - val_loss: 0.1367 - val_last_timestep_mse: 0.1132
# Epoch 74/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1320 - last_timestep_mse: 0.1120 - val_loss: 0.1308 - val_last_timestep_mse: 0.1144
# Epoch 75/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1311 - last_timestep_mse: 0.1086 - val_loss: 0.1278 - val_last_timestep_mse: 0.1256
# Epoch 76/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1295 - last_timestep_mse: 0.1131 - val_loss: 0.1370 - val_last_timestep_mse: 0.1387
# Epoch 77/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1347 - last_timestep_mse: 0.1168 - val_loss: 0.1305 - val_last_timestep_mse: 0.1300
# Epoch 78/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1301 - last_timestep_mse: 0.1128 - val_loss: 0.1252 - val_last_timestep_mse: 0.1264
# Epoch 79/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1250 - last_timestep_mse: 0.1055 - val_loss: 0.1216 - val_last_timestep_mse: 0.1177
# Epoch 80/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1232 - last_timestep_mse: 0.1035 - val_loss: 0.1223 - val_last_timestep_mse: 0.1140
# Epoch 81/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1222 - last_timestep_mse: 0.1030 - val_loss: 0.1208 - val_last_timestep_mse: 0.1134
# Epoch 82/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1223 - last_timestep_mse: 0.1042 - val_loss: 0.1195 - val_last_timestep_mse: 0.1135
# Epoch 83/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1208 - last_timestep_mse: 0.1029 - val_loss: 0.1185 - val_last_timestep_mse: 0.1115
# Epoch 84/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1197 - last_timestep_mse: 0.1001 - val_loss: 0.1186 - val_last_timestep_mse: 0.1081
# Epoch 85/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1201 - last_timestep_mse: 0.0997 - val_loss: 0.1180 - val_last_timestep_mse: 0.1108
# Epoch 86/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1190 - last_timestep_mse: 0.1001 - val_loss: 0.1187 - val_last_timestep_mse: 0.1166
# Epoch 87/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1186 - last_timestep_mse: 0.1017 - val_loss: 0.1261 - val_last_timestep_mse: 0.1259
# Epoch 88/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1226 - last_timestep_mse: 0.1068 - val_loss: 0.1233 - val_last_timestep_mse: 0.1168
# Epoch 89/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1215 - last_timestep_mse: 0.1030 - val_loss: 0.1186 - val_last_timestep_mse: 0.1026
# Epoch 90/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1187 - last_timestep_mse: 0.0987 - val_loss: 0.1209 - val_last_timestep_mse: 0.1020
# Epoch 91/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1192 - last_timestep_mse: 0.0971 - val_loss: 0.1177 - val_last_timestep_mse: 0.0964
# Epoch 92/200
# 8/8 [==============================] - 1s 164ms/step - loss: 0.1179 - last_timestep_mse: 0.0966 - val_loss: 0.1152 - val_last_timestep_mse: 0.1007
# Epoch 93/200
# 8/8 [==============================] - 1s 156ms/step - loss: 0.1154 - last_timestep_mse: 0.0969 - val_loss: 0.1151 - val_last_timestep_mse: 0.1037
# Epoch 94/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.1166 - last_timestep_mse: 0.0967 - val_loss: 0.1190 - val_last_timestep_mse: 0.1112
# Epoch 95/200
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1185 - last_timestep_mse: 0.1003 - val_loss: 0.1247 - val_last_timestep_mse: 0.1256
# Epoch 96/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1201 - last_timestep_mse: 0.1066 - val_loss: 0.1203 - val_last_timestep_mse: 0.1190
# Epoch 97/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1193 - last_timestep_mse: 0.1073 - val_loss: 0.1150 - val_last_timestep_mse: 0.1042
# Epoch 98/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1166 - last_timestep_mse: 0.1003 - val_loss: 0.1130 - val_last_timestep_mse: 0.0988
# Epoch 99/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1145 - last_timestep_mse: 0.0938 - val_loss: 0.1127 - val_last_timestep_mse: 0.1020
# Epoch 100/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1149 - last_timestep_mse: 0.0933 - val_loss: 0.1128 - val_last_timestep_mse: 0.1031
# Epoch 101/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1141 - last_timestep_mse: 0.0929 - val_loss: 0.1130 - val_last_timestep_mse: 0.1003
# Epoch 102/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1143 - last_timestep_mse: 0.0926 - val_loss: 0.1139 - val_last_timestep_mse: 0.1012
# Epoch 103/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1144 - last_timestep_mse: 0.0962 - val_loss: 0.1140 - val_last_timestep_mse: 0.1108
# Epoch 104/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1134 - last_timestep_mse: 0.0978 - val_loss: 0.1173 - val_last_timestep_mse: 0.1195
# Epoch 105/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1170 - last_timestep_mse: 0.1002 - val_loss: 0.1152 - val_last_timestep_mse: 0.1051
# Epoch 106/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1146 - last_timestep_mse: 0.0947 - val_loss: 0.1108 - val_last_timestep_mse: 0.1007
# Epoch 107/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1121 - last_timestep_mse: 0.0942 - val_loss: 0.1095 - val_last_timestep_mse: 0.0992
# Epoch 108/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1124 - last_timestep_mse: 0.0930 - val_loss: 0.1116 - val_last_timestep_mse: 0.1015
# Epoch 109/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1122 - last_timestep_mse: 0.0921 - val_loss: 0.1110 - val_last_timestep_mse: 0.1048
# Epoch 110/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1127 - last_timestep_mse: 0.0930 - val_loss: 0.1096 - val_last_timestep_mse: 0.1016
# Epoch 111/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1101 - last_timestep_mse: 0.0907 - val_loss: 0.1106 - val_last_timestep_mse: 0.1062
# Epoch 112/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1103 - last_timestep_mse: 0.0910 - val_loss: 0.1107 - val_last_timestep_mse: 0.1066
# Epoch 113/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1109 - last_timestep_mse: 0.0914 - val_loss: 0.1092 - val_last_timestep_mse: 0.1061
# Epoch 114/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1113 - last_timestep_mse: 0.0942 - val_loss: 0.1122 - val_last_timestep_mse: 0.1118
# Epoch 115/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1121 - last_timestep_mse: 0.0993 - val_loss: 0.1104 - val_last_timestep_mse: 0.1100
# Epoch 116/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1111 - last_timestep_mse: 0.0960 - val_loss: 0.1091 - val_last_timestep_mse: 0.0999
# Epoch 117/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1094 - last_timestep_mse: 0.0888 - val_loss: 0.1084 - val_last_timestep_mse: 0.0972
# Epoch 118/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1093 - last_timestep_mse: 0.0884 - val_loss: 0.1083 - val_last_timestep_mse: 0.1040
# Epoch 119/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1080 - last_timestep_mse: 0.0901 - val_loss: 0.1066 - val_last_timestep_mse: 0.0993
# Epoch 120/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1071 - last_timestep_mse: 0.0875 - val_loss: 0.1064 - val_last_timestep_mse: 0.1008
# Epoch 121/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1071 - last_timestep_mse: 0.0879 - val_loss: 0.1067 - val_last_timestep_mse: 0.1015
# Epoch 122/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1069 - last_timestep_mse: 0.0887 - val_loss: 0.1069 - val_last_timestep_mse: 0.1031
# Epoch 123/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1081 - last_timestep_mse: 0.0915 - val_loss: 0.1086 - val_last_timestep_mse: 0.1066
# Epoch 124/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1079 - last_timestep_mse: 0.0931 - val_loss: 0.1093 - val_last_timestep_mse: 0.1051
# Epoch 125/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1077 - last_timestep_mse: 0.0916 - val_loss: 0.1073 - val_last_timestep_mse: 0.0991
# Epoch 126/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1074 - last_timestep_mse: 0.0924 - val_loss: 0.1056 - val_last_timestep_mse: 0.0929
# Epoch 127/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1073 - last_timestep_mse: 0.0880 - val_loss: 0.1072 - val_last_timestep_mse: 0.0959
# Epoch 128/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1119 - last_timestep_mse: 0.0950 - val_loss: 0.1139 - val_last_timestep_mse: 0.0992
# Epoch 129/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1127 - last_timestep_mse: 0.0961 - val_loss: 0.1109 - val_last_timestep_mse: 0.0987
# Epoch 130/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1115 - last_timestep_mse: 0.0917 - val_loss: 0.1061 - val_last_timestep_mse: 0.0983
# Epoch 131/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1072 - last_timestep_mse: 0.0899 - val_loss: 0.1065 - val_last_timestep_mse: 0.0981
# Epoch 132/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1071 - last_timestep_mse: 0.0917 - val_loss: 0.1074 - val_last_timestep_mse: 0.1005
# Epoch 133/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1080 - last_timestep_mse: 0.0938 - val_loss: 0.1153 - val_last_timestep_mse: 0.1112
# Epoch 134/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1117 - last_timestep_mse: 0.1033 - val_loss: 0.1126 - val_last_timestep_mse: 0.1065
# Epoch 135/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1133 - last_timestep_mse: 0.0964 - val_loss: 0.1102 - val_last_timestep_mse: 0.0962
# Epoch 136/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1123 - last_timestep_mse: 0.0933 - val_loss: 0.1090 - val_last_timestep_mse: 0.0980
# Epoch 137/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1127 - last_timestep_mse: 0.0938 - val_loss: 0.1122 - val_last_timestep_mse: 0.1072
# Epoch 138/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1105 - last_timestep_mse: 0.0932 - val_loss: 0.1079 - val_last_timestep_mse: 0.1034
# Epoch 139/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1080 - last_timestep_mse: 0.0916 - val_loss: 0.1080 - val_last_timestep_mse: 0.0980
# Epoch 140/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1082 - last_timestep_mse: 0.0893 - val_loss: 0.1062 - val_last_timestep_mse: 0.1030
# Epoch 141/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1086 - last_timestep_mse: 0.0924 - val_loss: 0.1071 - val_last_timestep_mse: 0.1066
# Epoch 142/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1065 - last_timestep_mse: 0.0904 - val_loss: 0.1059 - val_last_timestep_mse: 0.1006
# Epoch 143/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1062 - last_timestep_mse: 0.0874 - val_loss: 0.1084 - val_last_timestep_mse: 0.1022
# Epoch 144/200
# 8/8 [==============================] - 1s 113ms/step - loss: 0.1076 - last_timestep_mse: 0.0901 - val_loss: 0.1052 - val_last_timestep_mse: 0.0996
# Epoch 145/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1051 - last_timestep_mse: 0.0894 - val_loss: 0.1025 - val_last_timestep_mse: 0.0946
# Epoch 146/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1030 - last_timestep_mse: 0.0886 - val_loss: 0.1029 - val_last_timestep_mse: 0.0926
# Epoch 147/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1029 - last_timestep_mse: 0.0881 - val_loss: 0.1042 - val_last_timestep_mse: 0.0917
# Epoch 148/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1039 - last_timestep_mse: 0.0863 - val_loss: 0.1045 - val_last_timestep_mse: 0.0942
# Epoch 149/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1043 - last_timestep_mse: 0.0893 - val_loss: 0.1036 - val_last_timestep_mse: 0.0941
# Epoch 150/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1053 - last_timestep_mse: 0.0909 - val_loss: 0.1022 - val_last_timestep_mse: 0.0964
# Epoch 151/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1049 - last_timestep_mse: 0.0900 - val_loss: 0.1044 - val_last_timestep_mse: 0.1015
# Epoch 152/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1049 - last_timestep_mse: 0.0863 - val_loss: 0.1052 - val_last_timestep_mse: 0.1061
# Epoch 153/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1053 - last_timestep_mse: 0.0904 - val_loss: 0.1049 - val_last_timestep_mse: 0.1027
# Epoch 154/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1050 - last_timestep_mse: 0.0886 - val_loss: 0.1046 - val_last_timestep_mse: 0.1015
# Epoch 155/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1048 - last_timestep_mse: 0.0882 - val_loss: 0.1020 - val_last_timestep_mse: 0.0954
# Epoch 156/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1042 - last_timestep_mse: 0.0916 - val_loss: 0.1039 - val_last_timestep_mse: 0.0919
# Epoch 157/200
# 8/8 [==============================] - 1s 123ms/step - loss: 0.1035 - last_timestep_mse: 0.0899 - val_loss: 0.1047 - val_last_timestep_mse: 0.0908
# Epoch 158/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1032 - last_timestep_mse: 0.0886 - val_loss: 0.1051 - val_last_timestep_mse: 0.0894
# Epoch 159/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1050 - last_timestep_mse: 0.0892 - val_loss: 0.1025 - val_last_timestep_mse: 0.0873
# Epoch 160/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1067 - last_timestep_mse: 0.0906 - val_loss: 0.1052 - val_last_timestep_mse: 0.1005
# Epoch 161/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1053 - last_timestep_mse: 0.0916 - val_loss: 0.1028 - val_last_timestep_mse: 0.0928
# Epoch 162/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1049 - last_timestep_mse: 0.0863 - val_loss: 0.1039 - val_last_timestep_mse: 0.1017
# Epoch 163/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1052 - last_timestep_mse: 0.0896 - val_loss: 0.1063 - val_last_timestep_mse: 0.1023
# Epoch 164/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1042 - last_timestep_mse: 0.0911 - val_loss: 0.1028 - val_last_timestep_mse: 0.0979
# Epoch 165/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1031 - last_timestep_mse: 0.0866 - val_loss: 0.0999 - val_last_timestep_mse: 0.0907
# Epoch 166/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1017 - last_timestep_mse: 0.0854 - val_loss: 0.1014 - val_last_timestep_mse: 0.0943
# Epoch 167/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1020 - last_timestep_mse: 0.0841 - val_loss: 0.1006 - val_last_timestep_mse: 0.0965
# Epoch 168/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1013 - last_timestep_mse: 0.0868 - val_loss: 0.1012 - val_last_timestep_mse: 0.0933
# Epoch 169/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1008 - last_timestep_mse: 0.0866 - val_loss: 0.1018 - val_last_timestep_mse: 0.0931
# Epoch 170/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1006 - last_timestep_mse: 0.0852 - val_loss: 0.0996 - val_last_timestep_mse: 0.0880
# Epoch 171/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1006 - last_timestep_mse: 0.0846 - val_loss: 0.1001 - val_last_timestep_mse: 0.0866
# Epoch 172/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1024 - last_timestep_mse: 0.0840 - val_loss: 0.1022 - val_last_timestep_mse: 0.0946
# Epoch 173/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1049 - last_timestep_mse: 0.0900 - val_loss: 0.1036 - val_last_timestep_mse: 0.1019
# Epoch 174/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1032 - last_timestep_mse: 0.0884 - val_loss: 0.1013 - val_last_timestep_mse: 0.0955
# Epoch 175/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1017 - last_timestep_mse: 0.0873 - val_loss: 0.1048 - val_last_timestep_mse: 0.0947
# Epoch 176/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1032 - last_timestep_mse: 0.0869 - val_loss: 0.1027 - val_last_timestep_mse: 0.0882
# Epoch 177/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1032 - last_timestep_mse: 0.0861 - val_loss: 0.1012 - val_last_timestep_mse: 0.0901
# Epoch 178/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1006 - last_timestep_mse: 0.0846 - val_loss: 0.1004 - val_last_timestep_mse: 0.0836
# Epoch 179/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0998 - last_timestep_mse: 0.0836 - val_loss: 0.0985 - val_last_timestep_mse: 0.0874
# Epoch 180/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1009 - last_timestep_mse: 0.0839 - val_loss: 0.1003 - val_last_timestep_mse: 0.0937
# Epoch 181/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1010 - last_timestep_mse: 0.0876 - val_loss: 0.1006 - val_last_timestep_mse: 0.0912
# Epoch 182/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1012 - last_timestep_mse: 0.0881 - val_loss: 0.1039 - val_last_timestep_mse: 0.0954
# Epoch 183/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1037 - last_timestep_mse: 0.0885 - val_loss: 0.1029 - val_last_timestep_mse: 0.0976
# Epoch 184/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1055 - last_timestep_mse: 0.0876 - val_loss: 0.1049 - val_last_timestep_mse: 0.0873
# Epoch 185/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1063 - last_timestep_mse: 0.0855 - val_loss: 0.1017 - val_last_timestep_mse: 0.0938
# Epoch 186/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1039 - last_timestep_mse: 0.0875 - val_loss: 0.1029 - val_last_timestep_mse: 0.0905
# Epoch 187/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1018 - last_timestep_mse: 0.0881 - val_loss: 0.1069 - val_last_timestep_mse: 0.0932
# Epoch 188/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1031 - last_timestep_mse: 0.0866 - val_loss: 0.1049 - val_last_timestep_mse: 0.1016
# Epoch 189/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1023 - last_timestep_mse: 0.0876 - val_loss: 0.1048 - val_last_timestep_mse: 0.0931
# Epoch 190/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1023 - last_timestep_mse: 0.0872 - val_loss: 0.1069 - val_last_timestep_mse: 0.0972
# Epoch 191/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1031 - last_timestep_mse: 0.0885 - val_loss: 0.1073 - val_last_timestep_mse: 0.1030
# Epoch 192/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1040 - last_timestep_mse: 0.0939 - val_loss: 0.1121 - val_last_timestep_mse: 0.1020
# Epoch 193/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1066 - last_timestep_mse: 0.0944 - val_loss: 0.1254 - val_last_timestep_mse: 0.1116
# Epoch 194/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1238 - last_timestep_mse: 0.1038 - val_loss: 0.1240 - val_last_timestep_mse: 0.1094
# Epoch 195/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1194 - last_timestep_mse: 0.1006 - val_loss: 0.1107 - val_last_timestep_mse: 0.1073
# Epoch 196/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1102 - last_timestep_mse: 0.0937 - val_loss: 0.1082 - val_last_timestep_mse: 0.0904
# Epoch 197/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1084 - last_timestep_mse: 0.0902 - val_loss: 0.1016 - val_last_timestep_mse: 0.0862
# Epoch 198/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1020 - last_timestep_mse: 0.0836 - val_loss: 0.1000 - val_last_timestep_mse: 0.0975
# Epoch 199/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1007 - last_timestep_mse: 0.0848 - val_loss: 0.0996 - val_last_timestep_mse: 0.0986
# Epoch 200/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1001 - last_timestep_mse: 0.0852 - val_loss: 0.1014 - val_last_timestep_mse: 0.0995

# %%
#predict
y_pred = model.predict((X_test[0])[np.newaxis,...])

#Inverse transform scaled data
y_true = scaler.inverse_transform(y_test[0,-1].reshape(-1,1))
y_pred = scaler.inverse_transform(y_pred.squeeze()[-1,:].reshape(-1,1))

plt.plot(y_true,label='true')
plt.plot(y_pred,'r',label='prediction')
plt.legend()
plt.xlabel('hour')
plt.ylabel('MW')
plt.show()
# Out:
# WARNING:tensorflow:7 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A3D24BCE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

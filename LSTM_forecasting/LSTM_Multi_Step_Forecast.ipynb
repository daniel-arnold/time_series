# %%
"""
Multi-step ahead forecasting
Forecasting n_ahead steps all at once using a LSTM network
"""

#Imports
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
#Load Data
data = pd.read_csv('data/AEP_hourly.csv', index_col=0, parse_dates=True)

#Sort the dataframe
data.sort_values('Datetime', inplace=True)

#scale the timeseries using standard scaler
ts = np.asarray(data['AEP_MW']).reshape(-1,1)
scaler = preprocessing.StandardScaler().fit(ts)
ts_scaled = list(scaler.transform(ts))

# %%
#create 3D array of timeseries of fixed length
n_ahead = 24
n_lag = n_ahead*14

max_idx = int(np.floor(len(ts_scaled) / (n_lag + n_ahead)))

i=0
series = []
for i in range(0, max_idx):
    n = n_lag + n_ahead
    series.append(ts_scaled[i*n : (i+1) * n])

#create training matrix and target vector
X = np.asarray(series)[:,0:n_lag,:]
y_plot = np.asarray(series)[:,n_lag:,:].squeeze()
y = np.empty((np.shape(X)[0], np.shape(X)[1], n_ahead))


for i in range(1, n_ahead+1):
    y[:,:,i-1] = np.asarray(series)[:,i:i+n_lag,0]

# %%
#create training, validation, and testing sets
train_valid_test = [0.7,0.2,0.1]
train_valid_test_idx = np.floor(np.asarray(train_valid_test) * max_idx).astype(int)
X_train, y_train = X[0:train_valid_test_idx[0],:,:], y[0:train_valid_test_idx[0],:,:]
X_valid, y_valid = X[0:train_valid_test_idx[1],:,:], y[0:train_valid_test_idx[1],:,:]
X_test, y_test = X[0:train_valid_test_idx[2],:,:], y[0:train_valid_test_idx[2],:,:]

# %%
#LSTM
num_neurons = 30
model = keras.models.Sequential([
    keras.layers.LSTM(num_neurons, return_sequences=True, input_shape=[None,1]),
    keras.layers.LSTM(num_neurons, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(n_ahead))
    ])

#custom loss function
def last_timestep_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:,-1], Y_pred[:,-1])

#compile model
lr = 0.01
opt = keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=opt, loss='mse', metrics=[last_timestep_mse])

epochs = 200

#create a dict for keras training args
keras_dict = {
    'x':X_train,
    'y':y_train,
    'epochs':epochs,
    'shuffle':False,
    'validation_data':(X_valid,y_valid)
}

#fit the model
model.fit(**keras_dict)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function last_timestep_mse at 0x000002987F87BCA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function last_timestep_mse at 0x000002987F87BCA0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 8/8 [==============================] - 1s 159ms/step - loss: 0.8148 - last_timestep_mse: 0.7669 - val_loss: 0.6366 - val_last_timestep_mse: 0.5459
# Epoch 2/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6011 - last_timestep_mse: 0.5699 - val_loss: 0.5206 - val_last_timestep_mse: 0.4902
# Epoch 3/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.4773 - last_timestep_mse: 0.4619 - val_loss: 0.3950 - val_last_timestep_mse: 0.3951
# Epoch 4/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.3692 - last_timestep_mse: 0.3497 - val_loss: 0.3328 - val_last_timestep_mse: 0.3315
# Epoch 5/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3236 - last_timestep_mse: 0.3117 - val_loss: 0.3032 - val_last_timestep_mse: 0.3200
# Epoch 6/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.3000 - last_timestep_mse: 0.2856 - val_loss: 0.2863 - val_last_timestep_mse: 0.3159
# Epoch 7/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2822 - last_timestep_mse: 0.2623 - val_loss: 0.2851 - val_last_timestep_mse: 0.3164
# Epoch 8/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2698 - last_timestep_mse: 0.2575 - val_loss: 0.2626 - val_last_timestep_mse: 0.3057
# Epoch 9/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2552 - last_timestep_mse: 0.2403 - val_loss: 0.2511 - val_last_timestep_mse: 0.3081
# Epoch 10/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2424 - last_timestep_mse: 0.2337 - val_loss: 0.2356 - val_last_timestep_mse: 0.2764
# Epoch 11/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2333 - last_timestep_mse: 0.2186 - val_loss: 0.2322 - val_last_timestep_mse: 0.2818
# Epoch 12/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2292 - last_timestep_mse: 0.2142 - val_loss: 0.2227 - val_last_timestep_mse: 0.2751
# Epoch 13/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2181 - last_timestep_mse: 0.2024 - val_loss: 0.2183 - val_last_timestep_mse: 0.2972
# Epoch 14/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2102 - last_timestep_mse: 0.1979 - val_loss: 0.1871 - val_last_timestep_mse: 0.2170
# Epoch 15/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1932 - last_timestep_mse: 0.1828 - val_loss: 0.1919 - val_last_timestep_mse: 0.2314
# Epoch 16/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1898 - last_timestep_mse: 0.1803 - val_loss: 0.1757 - val_last_timestep_mse: 0.2010
# Epoch 17/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1849 - last_timestep_mse: 0.1676 - val_loss: 0.1743 - val_last_timestep_mse: 0.1939
# Epoch 18/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1781 - last_timestep_mse: 0.1612 - val_loss: 0.1708 - val_last_timestep_mse: 0.2026
# Epoch 19/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1744 - last_timestep_mse: 0.1605 - val_loss: 0.1694 - val_last_timestep_mse: 0.2007
# Epoch 20/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1745 - last_timestep_mse: 0.1563 - val_loss: 0.1636 - val_last_timestep_mse: 0.1734
# Epoch 21/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1704 - last_timestep_mse: 0.1542 - val_loss: 0.1670 - val_last_timestep_mse: 0.2016
# Epoch 22/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1702 - last_timestep_mse: 0.1568 - val_loss: 0.1560 - val_last_timestep_mse: 0.1656
# Epoch 23/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1672 - last_timestep_mse: 0.1484 - val_loss: 0.1554 - val_last_timestep_mse: 0.1624
# Epoch 24/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1662 - last_timestep_mse: 0.1456 - val_loss: 0.1586 - val_last_timestep_mse: 0.1760
# Epoch 25/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1641 - last_timestep_mse: 0.1432 - val_loss: 0.1508 - val_last_timestep_mse: 0.1525
# Epoch 26/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.1601 - last_timestep_mse: 0.1377 - val_loss: 0.1522 - val_last_timestep_mse: 0.1574
# Epoch 27/200
# 8/8 [==============================] - 1s 118ms/step - loss: 0.1587 - last_timestep_mse: 0.1348 - val_loss: 0.1502 - val_last_timestep_mse: 0.1560
# Epoch 28/200
# 8/8 [==============================] - 1s 114ms/step - loss: 0.1575 - last_timestep_mse: 0.1337 - val_loss: 0.1468 - val_last_timestep_mse: 0.1488
# Epoch 29/200
# 8/8 [==============================] - 1s 114ms/step - loss: 0.1568 - last_timestep_mse: 0.1343 - val_loss: 0.1501 - val_last_timestep_mse: 0.1498
# Epoch 30/200
# 8/8 [==============================] - 1s 114ms/step - loss: 0.1552 - last_timestep_mse: 0.1309 - val_loss: 0.1438 - val_last_timestep_mse: 0.1352
# Epoch 31/200
# 8/8 [==============================] - 1s 131ms/step - loss: 0.1534 - last_timestep_mse: 0.1281 - val_loss: 0.1436 - val_last_timestep_mse: 0.1418
# Epoch 32/200
# 8/8 [==============================] - 1s 126ms/step - loss: 0.1522 - last_timestep_mse: 0.1290 - val_loss: 0.1417 - val_last_timestep_mse: 0.1352
# Epoch 33/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1487 - last_timestep_mse: 0.1255 - val_loss: 0.1432 - val_last_timestep_mse: 0.1465
# Epoch 34/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1492 - last_timestep_mse: 0.1258 - val_loss: 0.1392 - val_last_timestep_mse: 0.1328
# Epoch 35/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1459 - last_timestep_mse: 0.1224 - val_loss: 0.1462 - val_last_timestep_mse: 0.1482
# Epoch 36/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1500 - last_timestep_mse: 0.1239 - val_loss: 0.1394 - val_last_timestep_mse: 0.1303
# Epoch 37/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1452 - last_timestep_mse: 0.1215 - val_loss: 0.1461 - val_last_timestep_mse: 0.1509
# Epoch 38/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1482 - last_timestep_mse: 0.1250 - val_loss: 0.1355 - val_last_timestep_mse: 0.1343
# Epoch 39/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1428 - last_timestep_mse: 0.1205 - val_loss: 0.1366 - val_last_timestep_mse: 0.1281
# Epoch 40/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1403 - last_timestep_mse: 0.1165 - val_loss: 0.1374 - val_last_timestep_mse: 0.1305
# Epoch 41/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1396 - last_timestep_mse: 0.1144 - val_loss: 0.1288 - val_last_timestep_mse: 0.1222
# Epoch 42/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1352 - last_timestep_mse: 0.1126 - val_loss: 0.1312 - val_last_timestep_mse: 0.1280
# Epoch 43/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1359 - last_timestep_mse: 0.1142 - val_loss: 0.1298 - val_last_timestep_mse: 0.1251
# Epoch 44/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1356 - last_timestep_mse: 0.1140 - val_loss: 0.1269 - val_last_timestep_mse: 0.1173
# Epoch 45/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1339 - last_timestep_mse: 0.1107 - val_loss: 0.1294 - val_last_timestep_mse: 0.1200
# Epoch 46/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1341 - last_timestep_mse: 0.1099 - val_loss: 0.1292 - val_last_timestep_mse: 0.1210
# Epoch 47/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1339 - last_timestep_mse: 0.1103 - val_loss: 0.1287 - val_last_timestep_mse: 0.1231
# Epoch 48/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1344 - last_timestep_mse: 0.1119 - val_loss: 0.1277 - val_last_timestep_mse: 0.1174
# Epoch 49/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1327 - last_timestep_mse: 0.1134 - val_loss: 0.1331 - val_last_timestep_mse: 0.1163
# Epoch 50/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1339 - last_timestep_mse: 0.1106 - val_loss: 0.1328 - val_last_timestep_mse: 0.1251
# Epoch 51/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1357 - last_timestep_mse: 0.1173 - val_loss: 0.1341 - val_last_timestep_mse: 0.1197
# Epoch 52/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1352 - last_timestep_mse: 0.1159 - val_loss: 0.1327 - val_last_timestep_mse: 0.1222
# Epoch 53/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1332 - last_timestep_mse: 0.1154 - val_loss: 0.1372 - val_last_timestep_mse: 0.1235
# Epoch 54/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1330 - last_timestep_mse: 0.1100 - val_loss: 0.1256 - val_last_timestep_mse: 0.1123
# Epoch 55/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1293 - last_timestep_mse: 0.1116 - val_loss: 0.1250 - val_last_timestep_mse: 0.1136
# Epoch 56/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1283 - last_timestep_mse: 0.1112 - val_loss: 0.1262 - val_last_timestep_mse: 0.1151
# Epoch 57/200
# 8/8 [==============================] - 1s 125ms/step - loss: 0.1277 - last_timestep_mse: 0.1091 - val_loss: 0.1233 - val_last_timestep_mse: 0.1156
# Epoch 58/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1249 - last_timestep_mse: 0.1062 - val_loss: 0.1232 - val_last_timestep_mse: 0.1120
# Epoch 59/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1241 - last_timestep_mse: 0.1027 - val_loss: 0.1243 - val_last_timestep_mse: 0.1142
# Epoch 60/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1242 - last_timestep_mse: 0.1058 - val_loss: 0.1246 - val_last_timestep_mse: 0.1112
# Epoch 61/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1244 - last_timestep_mse: 0.1050 - val_loss: 0.1178 - val_last_timestep_mse: 0.1032
# Epoch 62/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1212 - last_timestep_mse: 0.1044 - val_loss: 0.1192 - val_last_timestep_mse: 0.1051
# Epoch 63/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.1201 - last_timestep_mse: 0.1015 - val_loss: 0.1163 - val_last_timestep_mse: 0.1071
# Epoch 64/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1193 - last_timestep_mse: 0.1010 - val_loss: 0.1192 - val_last_timestep_mse: 0.1052
# Epoch 65/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1202 - last_timestep_mse: 0.0999 - val_loss: 0.1184 - val_last_timestep_mse: 0.1012
# Epoch 66/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1210 - last_timestep_mse: 0.1027 - val_loss: 0.1200 - val_last_timestep_mse: 0.1075
# Epoch 67/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1212 - last_timestep_mse: 0.1032 - val_loss: 0.1176 - val_last_timestep_mse: 0.1147
# Epoch 68/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1196 - last_timestep_mse: 0.1053 - val_loss: 0.1334 - val_last_timestep_mse: 0.1343
# Epoch 69/200
# 8/8 [==============================] - 1s 124ms/step - loss: 0.1270 - last_timestep_mse: 0.1117 - val_loss: 0.1236 - val_last_timestep_mse: 0.1040
# Epoch 70/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1236 - last_timestep_mse: 0.1036 - val_loss: 0.1210 - val_last_timestep_mse: 0.1088
# Epoch 71/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1216 - last_timestep_mse: 0.1056 - val_loss: 0.1207 - val_last_timestep_mse: 0.1105
# Epoch 72/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1202 - last_timestep_mse: 0.1056 - val_loss: 0.1220 - val_last_timestep_mse: 0.1035
# Epoch 73/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1206 - last_timestep_mse: 0.0994 - val_loss: 0.1175 - val_last_timestep_mse: 0.1109
# Epoch 74/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1174 - last_timestep_mse: 0.1009 - val_loss: 0.1156 - val_last_timestep_mse: 0.0955
# Epoch 75/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1164 - last_timestep_mse: 0.0944 - val_loss: 0.1158 - val_last_timestep_mse: 0.0990
# Epoch 76/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1161 - last_timestep_mse: 0.0964 - val_loss: 0.1114 - val_last_timestep_mse: 0.0910
# Epoch 77/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1155 - last_timestep_mse: 0.0966 - val_loss: 0.1115 - val_last_timestep_mse: 0.0922
# Epoch 78/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1151 - last_timestep_mse: 0.0959 - val_loss: 0.1113 - val_last_timestep_mse: 0.0911
# Epoch 79/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1159 - last_timestep_mse: 0.0963 - val_loss: 0.1083 - val_last_timestep_mse: 0.0934
# Epoch 80/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1156 - last_timestep_mse: 0.0966 - val_loss: 0.1095 - val_last_timestep_mse: 0.0938
# Epoch 81/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1153 - last_timestep_mse: 0.0946 - val_loss: 0.1120 - val_last_timestep_mse: 0.1046
# Epoch 82/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1144 - last_timestep_mse: 0.1000 - val_loss: 0.1222 - val_last_timestep_mse: 0.1161
# Epoch 83/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1178 - last_timestep_mse: 0.0957 - val_loss: 0.1143 - val_last_timestep_mse: 0.1134
# Epoch 84/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1140 - last_timestep_mse: 0.0929 - val_loss: 0.1121 - val_last_timestep_mse: 0.1027
# Epoch 85/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.1137 - last_timestep_mse: 0.0951 - val_loss: 0.1090 - val_last_timestep_mse: 0.1011
# Epoch 86/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1133 - last_timestep_mse: 0.0952 - val_loss: 0.1084 - val_last_timestep_mse: 0.0938
# Epoch 87/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1115 - last_timestep_mse: 0.0925 - val_loss: 0.1077 - val_last_timestep_mse: 0.0953
# Epoch 88/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1108 - last_timestep_mse: 0.0938 - val_loss: 0.1073 - val_last_timestep_mse: 0.0947
# Epoch 89/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1102 - last_timestep_mse: 0.0906 - val_loss: 0.1143 - val_last_timestep_mse: 0.1024
# Epoch 90/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1128 - last_timestep_mse: 0.0927 - val_loss: 0.1088 - val_last_timestep_mse: 0.1036
# Epoch 91/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1122 - last_timestep_mse: 0.0934 - val_loss: 0.1132 - val_last_timestep_mse: 0.1007
# Epoch 92/200
# 8/8 [==============================] - 1s 113ms/step - loss: 0.1153 - last_timestep_mse: 0.0943 - val_loss: 0.1113 - val_last_timestep_mse: 0.1002
# Epoch 93/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1129 - last_timestep_mse: 0.0937 - val_loss: 0.1071 - val_last_timestep_mse: 0.0992
# Epoch 94/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1100 - last_timestep_mse: 0.0903 - val_loss: 0.1061 - val_last_timestep_mse: 0.1014
# Epoch 95/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1090 - last_timestep_mse: 0.0916 - val_loss: 0.1074 - val_last_timestep_mse: 0.0934
# Epoch 96/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1098 - last_timestep_mse: 0.0918 - val_loss: 0.1045 - val_last_timestep_mse: 0.0971
# Epoch 97/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1087 - last_timestep_mse: 0.0911 - val_loss: 0.1121 - val_last_timestep_mse: 0.1008
# Epoch 98/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1103 - last_timestep_mse: 0.0915 - val_loss: 0.1091 - val_last_timestep_mse: 0.0992
# Epoch 99/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1089 - last_timestep_mse: 0.0892 - val_loss: 0.1041 - val_last_timestep_mse: 0.0924
# Epoch 100/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1064 - last_timestep_mse: 0.0857 - val_loss: 0.1101 - val_last_timestep_mse: 0.1039
# Epoch 101/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1083 - last_timestep_mse: 0.0908 - val_loss: 0.1027 - val_last_timestep_mse: 0.0967
# Epoch 102/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1061 - last_timestep_mse: 0.0883 - val_loss: 0.1039 - val_last_timestep_mse: 0.0952
# Epoch 103/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1069 - last_timestep_mse: 0.0893 - val_loss: 0.1038 - val_last_timestep_mse: 0.0875
# Epoch 104/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1076 - last_timestep_mse: 0.0889 - val_loss: 0.1044 - val_last_timestep_mse: 0.1032
# Epoch 105/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1062 - last_timestep_mse: 0.0910 - val_loss: 0.1107 - val_last_timestep_mse: 0.0988
# Epoch 106/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1077 - last_timestep_mse: 0.0924 - val_loss: 0.1103 - val_last_timestep_mse: 0.1000
# Epoch 107/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1076 - last_timestep_mse: 0.0885 - val_loss: 0.1090 - val_last_timestep_mse: 0.0933
# Epoch 108/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1088 - last_timestep_mse: 0.0937 - val_loss: 0.1081 - val_last_timestep_mse: 0.1019
# Epoch 109/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1110 - last_timestep_mse: 0.1011 - val_loss: 0.1140 - val_last_timestep_mse: 0.0959
# Epoch 110/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1090 - last_timestep_mse: 0.0921 - val_loss: 0.1081 - val_last_timestep_mse: 0.1009
# Epoch 111/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1074 - last_timestep_mse: 0.0928 - val_loss: 0.1074 - val_last_timestep_mse: 0.0984
# Epoch 112/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1072 - last_timestep_mse: 0.0897 - val_loss: 0.1138 - val_last_timestep_mse: 0.1024
# Epoch 113/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1093 - last_timestep_mse: 0.0937 - val_loss: 0.1171 - val_last_timestep_mse: 0.0977
# Epoch 114/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1111 - last_timestep_mse: 0.0884 - val_loss: 0.1255 - val_last_timestep_mse: 0.1313
# Epoch 115/200
# 8/8 [==============================] - 1s 121ms/step - loss: 0.1182 - last_timestep_mse: 0.1005 - val_loss: 0.1283 - val_last_timestep_mse: 0.1102
# Epoch 116/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1211 - last_timestep_mse: 0.1025 - val_loss: 0.1228 - val_last_timestep_mse: 0.1256
# Epoch 117/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1197 - last_timestep_mse: 0.1066 - val_loss: 0.1123 - val_last_timestep_mse: 0.1047
# Epoch 118/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1159 - last_timestep_mse: 0.1014 - val_loss: 0.1083 - val_last_timestep_mse: 0.0996
# Epoch 119/200
# 8/8 [==============================] - 1s 124ms/step - loss: 0.1128 - last_timestep_mse: 0.0929 - val_loss: 0.1103 - val_last_timestep_mse: 0.0984
# Epoch 120/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1109 - last_timestep_mse: 0.0909 - val_loss: 0.1092 - val_last_timestep_mse: 0.1035
# Epoch 121/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1092 - last_timestep_mse: 0.0941 - val_loss: 0.1077 - val_last_timestep_mse: 0.0975
# Epoch 122/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1080 - last_timestep_mse: 0.0904 - val_loss: 0.1058 - val_last_timestep_mse: 0.0932
# Epoch 123/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1087 - last_timestep_mse: 0.0894 - val_loss: 0.1036 - val_last_timestep_mse: 0.0938
# Epoch 124/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1073 - last_timestep_mse: 0.0908 - val_loss: 0.1003 - val_last_timestep_mse: 0.0943
# Epoch 125/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1029 - last_timestep_mse: 0.0888 - val_loss: 0.0997 - val_last_timestep_mse: 0.0936
# Epoch 126/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1028 - last_timestep_mse: 0.0886 - val_loss: 0.1003 - val_last_timestep_mse: 0.0975
# Epoch 127/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1014 - last_timestep_mse: 0.0859 - val_loss: 0.0999 - val_last_timestep_mse: 0.0959
# Epoch 128/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1006 - last_timestep_mse: 0.0853 - val_loss: 0.0989 - val_last_timestep_mse: 0.0953
# Epoch 129/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0996 - last_timestep_mse: 0.0856 - val_loss: 0.0964 - val_last_timestep_mse: 0.0893
# Epoch 130/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0989 - last_timestep_mse: 0.0859 - val_loss: 0.0987 - val_last_timestep_mse: 0.0849
# Epoch 131/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0996 - last_timestep_mse: 0.0852 - val_loss: 0.1012 - val_last_timestep_mse: 0.0861
# Epoch 132/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1016 - last_timestep_mse: 0.0830 - val_loss: 0.1021 - val_last_timestep_mse: 0.0932
# Epoch 133/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1023 - last_timestep_mse: 0.0843 - val_loss: 0.1013 - val_last_timestep_mse: 0.0995
# Epoch 134/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1013 - last_timestep_mse: 0.0896 - val_loss: 0.1037 - val_last_timestep_mse: 0.0933
# Epoch 135/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.1024 - last_timestep_mse: 0.0870 - val_loss: 0.1027 - val_last_timestep_mse: 0.0931
# Epoch 136/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1042 - last_timestep_mse: 0.0836 - val_loss: 0.1011 - val_last_timestep_mse: 0.0927
# Epoch 137/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1016 - last_timestep_mse: 0.0889 - val_loss: 0.0994 - val_last_timestep_mse: 0.0877
# Epoch 138/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1011 - last_timestep_mse: 0.0863 - val_loss: 0.1012 - val_last_timestep_mse: 0.0972
# Epoch 139/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.1002 - last_timestep_mse: 0.0882 - val_loss: 0.0984 - val_last_timestep_mse: 0.0841
# Epoch 140/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0994 - last_timestep_mse: 0.0823 - val_loss: 0.0981 - val_last_timestep_mse: 0.0863
# Epoch 141/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0993 - last_timestep_mse: 0.0842 - val_loss: 0.0974 - val_last_timestep_mse: 0.0879
# Epoch 142/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0982 - last_timestep_mse: 0.0816 - val_loss: 0.0940 - val_last_timestep_mse: 0.0819
# Epoch 143/200
# 8/8 [==============================] - 1s 115ms/step - loss: 0.0982 - last_timestep_mse: 0.0813 - val_loss: 0.0978 - val_last_timestep_mse: 0.0886
# Epoch 144/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0982 - last_timestep_mse: 0.0841 - val_loss: 0.1002 - val_last_timestep_mse: 0.0888
# Epoch 145/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0994 - last_timestep_mse: 0.0814 - val_loss: 0.0992 - val_last_timestep_mse: 0.0877
# Epoch 146/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0993 - last_timestep_mse: 0.0828 - val_loss: 0.0963 - val_last_timestep_mse: 0.0903
# Epoch 147/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0980 - last_timestep_mse: 0.0814 - val_loss: 0.0935 - val_last_timestep_mse: 0.0915
# Epoch 148/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0955 - last_timestep_mse: 0.0865 - val_loss: 0.0930 - val_last_timestep_mse: 0.0828
# Epoch 149/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0951 - last_timestep_mse: 0.0787 - val_loss: 0.0955 - val_last_timestep_mse: 0.0782
# Epoch 150/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0969 - last_timestep_mse: 0.0787 - val_loss: 0.0952 - val_last_timestep_mse: 0.0849
# Epoch 151/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0957 - last_timestep_mse: 0.0787 - val_loss: 0.0929 - val_last_timestep_mse: 0.0953
# Epoch 152/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0940 - last_timestep_mse: 0.0807 - val_loss: 0.0940 - val_last_timestep_mse: 0.0770
# Epoch 153/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0947 - last_timestep_mse: 0.0750 - val_loss: 0.0926 - val_last_timestep_mse: 0.0834
# Epoch 154/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0940 - last_timestep_mse: 0.0775 - val_loss: 0.0949 - val_last_timestep_mse: 0.0818
# Epoch 155/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0935 - last_timestep_mse: 0.0772 - val_loss: 0.0930 - val_last_timestep_mse: 0.0774
# Epoch 156/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0954 - last_timestep_mse: 0.0784 - val_loss: 0.0927 - val_last_timestep_mse: 0.0875
# Epoch 157/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0957 - last_timestep_mse: 0.0840 - val_loss: 0.0951 - val_last_timestep_mse: 0.0891
# Epoch 158/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0971 - last_timestep_mse: 0.0825 - val_loss: 0.1038 - val_last_timestep_mse: 0.0849
# Epoch 159/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0988 - last_timestep_mse: 0.0806 - val_loss: 0.0956 - val_last_timestep_mse: 0.0863
# Epoch 160/200
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0953 - last_timestep_mse: 0.0811 - val_loss: 0.0937 - val_last_timestep_mse: 0.0803
# Epoch 161/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0950 - last_timestep_mse: 0.0816 - val_loss: 0.0942 - val_last_timestep_mse: 0.0867
# Epoch 162/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0951 - last_timestep_mse: 0.0799 - val_loss: 0.0930 - val_last_timestep_mse: 0.0835
# Epoch 163/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0934 - last_timestep_mse: 0.0766 - val_loss: 0.0917 - val_last_timestep_mse: 0.0808
# Epoch 164/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0920 - last_timestep_mse: 0.0782 - val_loss: 0.0926 - val_last_timestep_mse: 0.0803
# Epoch 165/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0933 - last_timestep_mse: 0.0753 - val_loss: 0.0926 - val_last_timestep_mse: 0.0860
# Epoch 166/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0941 - last_timestep_mse: 0.0760 - val_loss: 0.0931 - val_last_timestep_mse: 0.0833
# Epoch 167/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0941 - last_timestep_mse: 0.0770 - val_loss: 0.0936 - val_last_timestep_mse: 0.0825
# Epoch 168/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0953 - last_timestep_mse: 0.0803 - val_loss: 0.0919 - val_last_timestep_mse: 0.0878
# Epoch 169/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0939 - last_timestep_mse: 0.0791 - val_loss: 0.0924 - val_last_timestep_mse: 0.0861
# Epoch 170/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0936 - last_timestep_mse: 0.0796 - val_loss: 0.0893 - val_last_timestep_mse: 0.0851
# Epoch 171/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0920 - last_timestep_mse: 0.0761 - val_loss: 0.0919 - val_last_timestep_mse: 0.0894
# Epoch 172/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0914 - last_timestep_mse: 0.0786 - val_loss: 0.0925 - val_last_timestep_mse: 0.0854
# Epoch 173/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0926 - last_timestep_mse: 0.0740 - val_loss: 0.0888 - val_last_timestep_mse: 0.0839
# Epoch 174/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0917 - last_timestep_mse: 0.0769 - val_loss: 0.0923 - val_last_timestep_mse: 0.0754
# Epoch 175/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0920 - last_timestep_mse: 0.0753 - val_loss: 0.0897 - val_last_timestep_mse: 0.0842
# Epoch 176/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0897 - last_timestep_mse: 0.0742 - val_loss: 0.0935 - val_last_timestep_mse: 0.0811
# Epoch 177/200
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0904 - last_timestep_mse: 0.0741 - val_loss: 0.0898 - val_last_timestep_mse: 0.0816
# Epoch 178/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0919 - last_timestep_mse: 0.0748 - val_loss: 0.0908 - val_last_timestep_mse: 0.0873
# Epoch 179/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0927 - last_timestep_mse: 0.0800 - val_loss: 0.0902 - val_last_timestep_mse: 0.0860
# Epoch 180/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0915 - last_timestep_mse: 0.0810 - val_loss: 0.0885 - val_last_timestep_mse: 0.0831
# Epoch 181/200
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0908 - last_timestep_mse: 0.0783 - val_loss: 0.0916 - val_last_timestep_mse: 0.0836
# Epoch 182/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0930 - last_timestep_mse: 0.0806 - val_loss: 0.0922 - val_last_timestep_mse: 0.0822
# Epoch 183/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0930 - last_timestep_mse: 0.0784 - val_loss: 0.0889 - val_last_timestep_mse: 0.0905
# Epoch 184/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0911 - last_timestep_mse: 0.0807 - val_loss: 0.0884 - val_last_timestep_mse: 0.0815
# Epoch 185/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0905 - last_timestep_mse: 0.0785 - val_loss: 0.0864 - val_last_timestep_mse: 0.0844
# Epoch 186/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0874 - last_timestep_mse: 0.0768 - val_loss: 0.0844 - val_last_timestep_mse: 0.0794
# Epoch 187/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0865 - last_timestep_mse: 0.0726 - val_loss: 0.0865 - val_last_timestep_mse: 0.0781
# Epoch 188/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0877 - last_timestep_mse: 0.0736 - val_loss: 0.0846 - val_last_timestep_mse: 0.0789
# Epoch 189/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0869 - last_timestep_mse: 0.0762 - val_loss: 0.0848 - val_last_timestep_mse: 0.0817
# Epoch 190/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0878 - last_timestep_mse: 0.0776 - val_loss: 0.0897 - val_last_timestep_mse: 0.0877
# Epoch 191/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0909 - last_timestep_mse: 0.0786 - val_loss: 0.0920 - val_last_timestep_mse: 0.0857
# Epoch 192/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0928 - last_timestep_mse: 0.0819 - val_loss: 0.0870 - val_last_timestep_mse: 0.0846
# Epoch 193/200
# 8/8 [==============================] - 1s 123ms/step - loss: 0.0894 - last_timestep_mse: 0.0767 - val_loss: 0.0878 - val_last_timestep_mse: 0.0887
# Epoch 194/200
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0904 - last_timestep_mse: 0.0788 - val_loss: 0.0985 - val_last_timestep_mse: 0.0947
# Epoch 195/200
# 8/8 [==============================] - 1s 114ms/step - loss: 0.0972 - last_timestep_mse: 0.0819 - val_loss: 0.0898 - val_last_timestep_mse: 0.0836
# Epoch 196/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0936 - last_timestep_mse: 0.0784 - val_loss: 0.0897 - val_last_timestep_mse: 0.0961
# Epoch 197/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0920 - last_timestep_mse: 0.0814 - val_loss: 0.0890 - val_last_timestep_mse: 0.0860
# Epoch 198/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0901 - last_timestep_mse: 0.0729 - val_loss: 0.0929 - val_last_timestep_mse: 0.0788
# Epoch 199/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0907 - last_timestep_mse: 0.0776 - val_loss: 0.0867 - val_last_timestep_mse: 0.0831
# Epoch 200/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0886 - last_timestep_mse: 0.0748 - val_loss: 0.0914 - val_last_timestep_mse: 0.0873

# %%
#predict
y_pred = model.predict((X_test[-1])[np.newaxis,...])

#Inverse transform scaled data
y_true = scaler.inverse_transform(y_test[-1,-1].reshape(-1,1))
y_pred = scaler.inverse_transform(y_pred.squeeze()[-1,:].reshape(-1,1))

plt.plot(y_true,label='true')
plt.plot(y_pred,'r',label='prediction')
plt.legend()
plt.xlabel('hour')
plt.ylabel('MW')
plt.show()
